# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariana-Rivas/Fundamentos/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
X="Aviones"
variableBooleana=True
print("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Aviones X True

# %%
base=input("Dame la base del triángulo")
altura=input("Dame la altura de un triángulo")
área= (int(base)*int(altura))/2
print("El area del triangulo es",área)
# Out:
# Dame la base del triángulo10
# Dame la altura de un triángulo15
# El area del triangulo es 75.0

# %%
z=10
a="Hola"
print(z*a)
# Out:
# HolaHolaHolaHolaHolaHolaHolaHolaHolaHola

# %%
numero1=20
numero2=40
if numero1>numero2:
  print("El numero", numero1, "es mayor que", numero2)
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# El numero 40 es mayor que 20
