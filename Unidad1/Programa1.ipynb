# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariana-Rivas/Fundamentos/blob/main/Unidad1/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingeniería en Inteligencia Artificial** **texto en negrita**
#
# #**Fundamentos de programacion**
# ##**Unidad1**
# ### práctica 1: Introduccion al lenguaje de programacion python}
# docente: **José Gabriel Rodríguez Rivas**
# Alumno: Rivas Fuentes Mariana Sarely
# Numero de control: 26041648

# %%
x=5
X="Aviones"
variableBooleana=True
print("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Aviones X True

# %%
base=input("Dame la base del triángulo")
altura=input("Dame la altura de un triángulo")
área= (int(base)*int(altura))/2
print("El area del triangulo es",área)

# %%
numero1=70
numero2=70
if numero1>numero2:
  print("El numero", numero1, "es mayor que", numero2)
else:
  print("El numero", numero2, "es mayor que", numero1)

# %%
Variable1=70
variable2=70
if variable1>variable2:
  print(variable1, "es mayor que", variable2)
  elif variable1==variable2:
    print(variable1, "y", variable2, "son iguales")
    else:
      print(variable2, "es mayor que", variable1)

# %%
10 > 5

# %%
5 > 10

# %%
10 > 5 and 5 < 10

# %%
10 > 5 and 5 > 10

# %%
10 > 5 or 5 > 10

# %%
edad = int(input("Dame tu edad"))
if edad <=10:
    print("Eres un niño")
elif edad <=18:
    print("Eres un adolescente")
elif edad <=30:
      print("Eres un adulto joven")
elif edad <=65:
        print("Eres un adulto")
else:   #Para cuando eres mayor a 66 años
          print("Eres un adulto mayor")

# %%
edad = int(input("Dame tu edad"))
if edad <=10:

# %%
edad=int(input("Dame tu edad"))
if edad >=66:
  print("Eres un adulto mayor")
elif edad >=31 and  edad <=65:
    print("Eres un adulto")
elif edad >=19 and edad <=30:
      print("Eres un adulto joven")
elif edad >=11 and edad <=18:
        print("Eres un niño")
else:
        print("Eres un niño")

# %%
tabla = 5
for i in range (1,11, 2):
  print(tabla, "x", i, "=", tabla*i)

# %%
tabla =int(input("Dame el número de la tabla"))
LimI=int(input("Dame el número de inicio"))
LimF=int(input("Dame el valor final"))
while LimF <= LimI:
print("El limF debe ser mayor que el inicial")
 LimF=int(input("dame limite final"))
Incremento=int(input("Dame el numero de los incrementos"))
for i in range(LimI, LimF, Incremento):
  print(tabla, "X", i, "=", tabla*i)

# %%
#En este caso está mal implementado la lógica porque
#al ser if's independientes se van a evaluar cada una de ellas
#y si ponemos por ejemplo edad=15 en casi todos los ifs
#se va a cumplir la condición y no es lo que queremos
edad=int(input("Dame tu edad"))
if edad >=65:
  print("Eres un adulto mayor")
if edad >=30:
    print("Eres un adulto")
if edad >=18:
      print("Eres un adulto joven")
if edad >=10:
        print("Eres un niño")
else:
        print("Eres un niño")

# %%
numero=1
while numero <=5:
  print (numero)
  numero=numero+1

# %% [markdown]
# #**Tema de listas**

# %%
alumnos=["Ana", "Luis", "Carlos", "Juan"]
print(alumnos)
print(alumnos[0])
print(alumnos[3])
print(alumnos[5]) #Esta instrucción marca error por que el índice o posición no existe

# %%
#Modificar un valor de la lista en un indice especifico
alumnos[1]="María Luisa"
print(alumnos)

# %%
#El metodo append agrega un elemento al final de la lista
alumnos.append("Karla")
print(alumnos)

# %%
#El método insert agrega un elemento a la lista en la posición especificada
alumnos.insert(2,"Cristina")
print(alumnos)

# %%
#Remove elimina un elemento especificando el valor del elemento
#Debe coincidir exactamente mayusculas y minusculas
alumnos.remove("Ana")
alumnos.remove("ana")#Esta marcaría error porque no está bien escrito
print(alumnos)

# %%
print(alumnos)

# %%
#Pop elimina el elemento item en la posición especificada
alumnos.pop(2)
print(alumnos)

# %%
#del también elimina el elemento o item en la posición especificada
del alumnos[3]
print(alumnos)

# %%
#La función led me permite conocer cuantos elementos tiene una lista
print("elementos en la lista de alumnos", len(alumnos))

# %%
alumnos.append("Anna")
alumnos.append("Ernesto")
for x in alumnos:
  print(x)

# %%
print(alumnos)
for x in alumnos:
  print(x)
  if x == "Anna":
    break #break forza a salir del ciclo, siempre y cuando se cumpla
          #La condición del if

# %%
software = ["python", "python y vs code", "AutoCAD", "SolidWorks", "Java"]
print(software)

# %%
if "python" in software:
  print("Python esta en la lista de software")
  else:
    print("Python no esta en la lista software")

# %%
#otra forma de recorrer o listar los elementos de una lista
for i in range( len(software) ):
  print(software[i])

  #forma tradicional
  print("\nlistar otra vez la lista")
  for x in software:
    print (x)

# %%
#2 Buscar por software
elif opcion==2:
  programa=input("\ngrese el software que desea buscar: ")
  print("\n--- Resultados---")
  encontrado=False
  for i in range(len(computadoras)):
    #la función (lower) convierte a minúscula el texto, de esta forma
    #nos aseguramos que el texto a buscar y la información de las líneas
    #este en minúscula y no tengamos problema de que no encuentra un programa
    #porque este escrito de forma diferente usando mayúsculas y minúsculas
    if programa-lower() in software[i].lower():
      print("ID:", computadoras[i])
      print("Aula:", aulas[i])
      print("software:", software[i])
      print("Estado:", estados[i])
      encontrado=True

if encontrado==False:
  print("No se encontraron computadoras con ese software.")

# %%
#3 solicitar préstamo
elif opcion==3:
  print("\n---SOLICITAR PRÉSTAMO---")
  num_control=input("\ngrese el número de control:")
  encontrado=False
  #Verificar si existe el alumno en la lista o no
  if num_control in alumno:
    #si esxiste, continuamos con el procedimiento
    encontrado=True
    id_computadora=input("Ingrese el ID de la computadora: ")
    encontrado2=False
    for i in range(len(computadoras)):
      if computadoras[i]==id_computadora:
        encontrado2=True
        if estados[i]=="Disponible"
        estados[i]="Prestada"
        print("Préstamo registrado correctamente.")
        print("computadora:", computadora[i])
        print("Aula:", aulas[i])
    else:
      print("Lcomputadora no está disponible.")
  if encontrado2==False:
    print("La computadora no existe.")
if encontrado1==False:
  print("El alumno no existe.")
